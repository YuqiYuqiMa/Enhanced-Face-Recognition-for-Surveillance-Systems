# %% [markdown]
# <a href="https://colab.research.google.com/github/YuqiYuqiMa/Enhanced-Face-Recognition-for-Surveillance-Systems/blob/main/SR_Gan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Env Setting

# %%
# %cd /content
# !mkdir SR
# %cd SR
# !mkdir data
# Out:
# /content
# /content/SR

# %%
# %cd /content
# !mkdir FD
# %cd FD
# !mkdir pretrain
# Out:
# /content
# /content/FD

# %%
# !pip install scipy==1.1.0
# !pip install numpy==1.10.4
# !pip install keras==2.2.4
# Out:
# Collecting scipy==1.1.0
#   Downloading https://files.pythonhosted.org/packages/40/de/0c22c6754370ba6b1fa8e53bd6e514d4a41a181125d405a501c215cbdbd6/scipy-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (31.2MB)
#      |████████████████████████████████| 31.2MB 171kB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from scipy==1.1.0) (1.19.5)
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# Successfully installed scipy-1.1.0
# Collecting numpy==1.10.4
#   Downloading https://files.pythonhosted.org/packages/1d/94/3ad9a865f1b0853f952eaa9878c59371ac907b768fe789547f573a6c9b39/numpy-1.10.4.tar.gz (4.1MB)
#      |████████████████████████████████| 4.1MB 5.7MB/s
# Building wheels for collected packages: numpy
#   Building wheel for numpy (setup.py) ... error
#   ERROR: Failed building wheel for numpy
#   Running setup.py clean for numpy
# Failed to build numpy
# ERROR: yellowbrick 0.9.1 has requirement numpy>=1.13.0, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: xarray 0.15.1 has requirement numpy>=1.15, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: umap-learn 0.5.1 has requirement numpy>=1.17, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: tifffile 2021.2.26 has requirement numpy>=1.15.1, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: tensorflow 2.4.1 has requirement numpy~=1.19.2, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: tensorflow-probability 0.12.1 has requirement numpy>=1.13.3, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: tensorflow-hub 0.11.0 has requirement numpy>=1.12.0, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: tensorboard 2.4.1 has requirement numpy>=1.12.0, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: statsmodels 0.10.2 has requirement numpy>=1.11, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: spacy 2.2.4 has requirement numpy>=1.15.0, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: seaborn 0.11.1 has requirement numpy>=1.15, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: scikit-learn 0.22.2.post1 has requirement numpy>=1.11.0, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: pywavelets 1.1.1 has requirement numpy>=1.13.3, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: pysndfile 1.3.8 has requirement numpy>=1.13.0, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: pymc3 3.7 has requirement numpy>=1.13.0, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: pyerfa 1.7.2 has requirement numpy>=1.16, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: pyarrow 3.0.0 has requirement numpy>=1.16.6, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: plotnine 0.6.0 has requirement numpy>=1.16.0, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: pandas 1.1.5 has requirement numpy>=1.15.4, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: opencv-python 4.1.2.30 has requirement numpy>=1.14.5, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: opencv-contrib-python 4.1.2.30 has requirement numpy>=1.14.5, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: numba 0.51.2 has requirement numpy>=1.15, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: nibabel 3.0.2 has requirement numpy>=1.12, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: matplotlib 3.2.2 has requirement numpy>=1.11, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: librosa 0.8.0 has requirement numpy>=1.15.0, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: jaxlib 0.1.60+cuda101 has requirement numpy<1.20,>=1.12, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: jax 0.2.9 has requirement numpy>=1.12, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: imgaug 0.2.9 has requirement numpy>=1.15.0, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: gensim 3.6.0 has requirement numpy>=1.11.3, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: fbprophet 0.7.1 has requirement numpy>=1.15.4, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: fastai 1.0.61 has requirement numpy>=1.15, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: cvxpy 1.0.31 has requirement numpy>=1.15, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: bokeh 2.1.1 has requirement numpy>=1.11.3, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: blis 0.4.1 has requirement numpy>=1.15.0, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: autograd 1.3 has requirement numpy>=1.12, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: astropy 4.2 has requirement numpy>=1.17, but you'll have numpy 1.10.4 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement numpy>=1.11.1, but you'll have numpy 1.10.4 which is incompatible.
# Installing collected packages: numpy
#   Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#     Running setup.py install for numpy ... error
#   Rolling back uninstall of numpy
#   Moving to /usr/bin/f2py
#    from /tmp/pip-uninstall-zgbipact/f2py
#   Moving to /usr/local/bin/f2py
#    from /tmp/pip-uninstall-kma25sfu/f2py
#   Moving to /usr/local/bin/f2py3
#    from /tmp/pip-uninstall-kma25sfu/f2py3
#   Moving to /usr/local/bin/f2py3.7
#    from /tmp/pip-uninstall-kma25sfu/f2py3.7
#   Moving to /usr/local/lib/python3.7/dist-packages/numpy-1.19.5.dist-info/
#    from /usr/local/lib/python3.7/dist-packages/~umpy-1.19.5.dist-info
#   Moving to /usr/local/lib/python3.7/dist-packages/numpy.libs/
#    from /usr/local/lib/python3.7/dist-packages/~umpy.libs
#   Moving to /usr/local/lib/python3.7/dist-packages/numpy/
#    from /usr/local/lib/python3.7/dist-packages/~umpy
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-zth2y9x3/numpy/setup.py'"'"'; __file__='"'"'/tmp/pip-install-zth2y9x3/numpy/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-o4uyt4lz/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.
# Collecting keras==2.2.4
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#      |████████████████████████████████| 317kB 5.4MB/s
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.19.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (3.13)
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 4.4MB/s
# Installing collected packages: keras-applications, keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.2.4 keras-applications-1.0.8

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %%
# !pip install tensorflow==1.15
# Out:
# Collecting tensorflow==1.15
#   Downloading https://files.pythonhosted.org/packages/92/2b/e3af15221da9ff323521565fa3324b0d7c7c5b1d7a8ca66984c8d59cb0ce/tensorflow-1.15.0-cp37-cp37m-manylinux2010_x86_64.whl (412.3MB)
#      |████████████████████████████████| 412.3MB 34kB/s
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.0.8)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.15.0)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 42.5MB/s
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 40.5MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (0.10.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (0.36.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (3.12.4)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.32.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (3.3.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.19.5)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.12.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.1.2)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (0.8.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (0.2.0)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15) (2.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (54.0.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.7.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.7.4.3)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=3c8b8258b9a13953073a1752eb9de3bf75f389777bc05bd7bc4078b7c5fa372e
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: tensorboard, tensorflow-estimator, gast, tensorflow
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# Successfully installed gast-0.2.2 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1

# %% [markdown]
# ###Mont Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Copy your data from drive to colab

# %%
# !pwd
# Out:
# /content/SR

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/
# %ls
# Out:
# /content/drive/MyDrive/Colab Notebooks
#  AJ_resized.zip                   Untitled0.ipynb
#  AJ.zip                           VoxelNet_datacreation
# 'Copy of hw2.ipynb'              'VoxelNet Data Preprocsssing'
# 'Copy of VoxelNet_datacreation'   VoxelNet.ipynb
# 'Face Detection'/                'VoxelNet Model Traing & Validation'
#  SR/

# %%
# !cp AJ_resized.zip /content/

# %% [markdown]
# ### UnZip

# %%
# !unzip "/content/AJ_resized.zip" -d /content/
# Out:
# Archive:  /content/AJ_resized.zip
#    creating: /content/content/SR/data/AJ/
#   inflating: /content/content/SR/data/AJ/346 resized.jpg
#   inflating: /content/content/SR/data/AJ/195 resized.jpg
#   inflating: /content/content/SR/data/AJ/34 resized.jpg
#   inflating: /content/content/SR/data/AJ/594 resized.jpg
#   inflating: /content/content/SR/data/AJ/714 resized.jpg
#   inflating: /content/content/SR/data/AJ/660 resized.jpg
#   inflating: /content/content/SR/data/AJ/730 resized.jpg
#   inflating: /content/content/SR/data/AJ/321 resized.jpg
#   inflating: /content/content/SR/data/AJ/457 resized.jpg
#   inflating: /content/content/SR/data/AJ/119 resized.jpg
#   inflating: /content/content/SR/data/AJ/51 resized.jpg
#   inflating: /content/content/SR/data/AJ/152 resized.jpg
#   inflating: /content/content/SR/data/AJ/740 resized.jpg
#   inflating: /content/content/SR/data/AJ/145 resized.jpg
#   inflating: /content/content/SR/data/AJ/790 resized.jpg
#   inflating: /content/content/SR/data/AJ/621 resized.jpg
#   inflating: /content/content/SR/data/AJ/391 resized.jpg
#   inflating: /content/content/SR/data/AJ/282 resized.jpg
#   inflating: /content/content/SR/data/AJ/141 resized.jpg
#   inflating: /content/content/SR/data/AJ/130 resized.jpg
#   inflating: /content/content/SR/data/AJ/94 resized.jpg
#   inflating: /content/content/SR/data/AJ/199 resized.jpg
#   inflating: /content/content/SR/data/AJ/172 resized.jpg
#   inflating: /content/content/SR/data/AJ/551 resized.jpg
#   inflating: /content/content/SR/data/AJ/222 resized.jpg
#   inflating: /content/content/SR/data/AJ/493 resized.jpg
#   inflating: /content/content/SR/data/AJ/375 resized.jpg
#   inflating: /content/content/SR/data/AJ/442 resized.jpg
#   inflating: /content/content/SR/data/AJ/184 resized.jpg
#   inflating: /content/content/SR/data/AJ/617 resized.jpg
#   inflating: /content/content/SR/data/AJ/792 resized.jpg
#   inflating: /content/content/SR/data/AJ/526 resized.jpg
#   inflating: /content/content/SR/data/AJ/53 resized.jpg
#   inflating: /content/content/SR/data/AJ/270 resized.jpg
#   inflating: /content/content/SR/data/AJ/322 resized.jpg
#   inflating: /content/content/SR/data/AJ/470 resized.jpg
#   inflating: /content/content/SR/data/AJ/520 resized.jpg
#   inflating: /content/content/SR/data/AJ/219 resized.jpg
#   inflating: /content/content/SR/data/AJ/343 resized.jpg
#   inflating: /content/content/SR/data/AJ/111 resized.jpg
#   inflating: /content/content/SR/data/AJ/449 resized.jpg
#   inflating: /content/content/SR/data/AJ/252 resized.jpg
#   inflating: /content/content/SR/data/AJ/302 resized.jpg
#   inflating: /content/content/SR/data/AJ/227 resized.jpg

# %% [markdown]
# ##SR

# %% [markdown]
# ###Build SRGan Model

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/deepak112/Keras-SRGAN
# Out:
# Cloning into 'Keras-SRGAN'...
# remote: Enumerating objects: 62, done.
# remote: Total 62 (delta 0), reused 0 (delta 0), pack-reused 62
# Unpacking objects: 100% (62/62), done.

# %%
# %cd /content/Keras-SRGAN/
# !python train.py --input_dir='/content/SR/data/AJ/' --output_dir='./output/' --model_save_dir='./model/' --batch_size=1 --epochs=10 --number_of_images=50 --train_test_ratio=0.8
# Out:
# /content/Keras-SRGAN
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2021-03-04 10:03:53.206494: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-03-04 10:03:53.211249: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2021-03-04 10:03:53.211582: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x556dc7447480 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-03-04 10:03:53.211618: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-03-04 10:03:53.213468: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-03-04 10:03:53.320969: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-04 10:03:53.322199: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x556dc7446d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-03-04 10:03:53.322239: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2021-03-04 10:03:53.322489: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-04 10:03:53.323347: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-03-04 10:03:53.323746: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-04 10:03:53.325112: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2021-03-04 10:03:53.326324: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2021-03-04 10:03:53.326745: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2021-03-04 10:03:53.328295: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2021-03-04 10:03:53.329480: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2021-03-04 10:03:53.332702: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-04 10:03:53.332841: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-04 10:03:53.333817: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-04 10:03:53.334893: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2021-03-04 10:03:53.334957: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-03-04 10:03:53.336407: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-04 10:03:53.336446: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2021-03-04 10:03:53.336474: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2021-03-04 10:03:53.336679: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-04 10:03:53.337969: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-03-04 10:03:53.338880: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-03-04 10:03:53.338956: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15224 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# --------------- Epoch 1 ---------------
#   0% 0/40 [00:00<?, ?it/s]2021-03-04 10:04:04.852585: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-03-04 10:04:05.549093: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# tcmalloc: large alloc 1207959552 bytes == 0x556e1b2dc000 @  0x7f667c5c4b6b 0x7f667c5e4379 0x7f661638bee7 0x7f661617951f 0x7f661603dde9 0x7f6616045c4f 0x7f661f821e22 0x7f661f82345e 0x7f661f823657 0x7f661f81be25 0x7f661f79b73a 0x7f661f79c8c5 0x7f661f688d1b 0x7f661f68a045 0x7f661f68bbf4 0x7f661f68e2ef 0x7f661f67c873 0x7f661f67e76c 0x7f661c598a3a 0x7f661c59a0f4 0x7f661c59c433 0x7f661c59dde7 0x7f6619369b3d 0x7f6619a10d93 0x7f6619a11aaa 0x7f6619366b24 0x7f6619366c12 0x7f661931fb5e 0x556dc482afd7 0x556dc482ade0 0x556dc489f244
# tcmalloc: large alloc 1207959552 bytes == 0x556e1b2dc000 @  0x7f667c5c4b6b 0x7f667c5e4379 0x7f661638bee7 0x7f661617951f 0x7f661603dde9 0x7f6616045c4f 0x7f661f821e22 0x7f661f82345e 0x7f661f823657 0x7f661f81be25 0x7f661f79b73a 0x7f661f79c8c5 0x7f661f688d1b 0x7f661f68a045 0x7f661f68bbf4 0x7f661f68e2ef 0x7f661f67c873 0x7f661f67e76c 0x7f661c598a3a 0x7f661c59a0f4 0x7f661c59c433 0x7f661c59dde7 0x7f6619369b3d 0x7f6619a10d93 0x7f6619a11aaa 0x7f6619366b24 0x7f6619366c12 0x7f661931fb5e 0x556dc482afd7 0x556dc482ade0 0x556dc489f244
# 100% 40/40 [00:44<00:00,  1.11s/it]
# discriminator_loss : 8.333736
# gan_loss : [0.0917867, 0.09159523, 0.19146836]
# 10
# --------------- Epoch 2 ---------------
# 100% 40/40 [00:17<00:00,  2.27it/s]
# discriminator_loss : 6.537041
# gan_loss : [0.07854059, 0.076934956, 1.6056358]
# --------------- Epoch 3 ---------------
# 100% 40/40 [00:17<00:00,  2.27it/s]
# discriminator_loss : 6.752144
# gan_loss : [0.088505164, 0.08779457, 0.71059525]
# --------------- Epoch 4 ---------------
# 100% 40/40 [00:17<00:00,  2.27it/s]
# discriminator_loss : 7.748187
# gan_loss : [0.066024564, 0.064471744, 1.5528194]
# --------------- Epoch 5 ---------------
# 100% 40/40 [00:17<00:00,  2.26it/s]
# discriminator_loss : 7.835101
# gan_loss : [0.077300616, 0.0758885, 1.4121181]
# 10
# --------------- Epoch 6 ---------------
# 100% 40/40 [00:17<00:00,  2.27it/s]
# discriminator_loss : 7.118403
# gan_loss : [0.063290104, 0.060701378, 2.5887253]
# --------------- Epoch 7 ---------------
# 100% 40/40 [00:17<00:00,  2.26it/s]
# discriminator_loss : 8.239969
# gan_loss : [0.07418753, 0.072333425, 1.8541032]
# --------------- Epoch 8 ---------------
# 100% 40/40 [00:17<00:00,  2.26it/s]
# discriminator_loss : 7.981598
# gan_loss : [0.057026606, 0.054964334, 2.0622733]
# --------------- Epoch 9 ---------------
# 100% 40/40 [00:17<00:00,  2.26it/s]
# discriminator_loss : 7.277956
# gan_loss : [0.06276544, 0.061755735, 1.0097095]
# --------------- Epoch 10 ---------------
# 100% 40/40 [00:17<00:00,  2.27it/s]
# discriminator_loss : 7.339356
# gan_loss : [0.035945166, 0.035084754, 0.86041176]
# 10

# %%
# %cd /content/SR/data/AJ/
# %ls -1 | wc -l
# Out:
# /content/SR/data/AJ
# 737

# %%
# %cd /content/
# Out:
# /content
# /content

# %%
from shutil import copyfile

with open('good_images.txt', 'r') as file:
    # You can directly iterate your lines through the file.
    for line in file:
        # Creating your list of numbers from your string.
        lineNumbers = line.strip().split(' ')
        for num in lineNumbers:
          if(len(num) > 1):
            copyfile('/content/SR/data/dir_001/Andrew Lincoln/' + num, '/content/SR/data/dir_001/AL/' + num)

# %% [markdown]
# ##Face Detection

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/Face\ Detection/pretrain
# %ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/Face Detection/pretrain
# yolov2_tiny-face.h5

# %%
# !cp yolov2_tiny-face.h5 /content/FD/pretrain/

# %% [markdown]
# ###Build the YOLOv2 Face Detection Model

# %%
from datetime import datetime
import numpy as np
import sys, getopt
import cv2
import os
from keras import backend as K

os.environ['KERAS_BACKEND'] = 'tensorflow'

from keras.models import load_model
from keras.preprocessing import image

#YOLOV1
#reference from https://github.com/xingwangsfu/caffe-yolo
def interpret_output_yolov1(output, img_width, img_height):
	classes = ["face"]
	w_img = img_width
	h_img = img_height
	threshold = 0.2
	iou_threshold = 0.5
	num_class = 1
	num_box = 2
	grid_size = 11
	probs = np.zeros((grid_size,grid_size,2,20))
	class_probs = np.reshape(output[0:grid_size*grid_size*num_class],(grid_size,grid_size,num_class))
	scales = np.reshape(output[grid_size*grid_size*num_class:grid_size*grid_size*num_class+grid_size*grid_size*2],(grid_size,grid_size,2))
	boxes = np.reshape(output[grid_size*grid_size*num_class+grid_size*grid_size*2:],(grid_size,grid_size,2,4))
	offset = np.transpose(np.reshape(np.array([np.arange(grid_size)]*grid_size*2),(2,grid_size,grid_size)),(1,2,0))

	boxes[:,:,:,0] += offset
	boxes[:,:,:,1] += np.transpose(offset,(1,0,2))
	boxes[:,:,:,0:2] = boxes[:,:,:,0:2] / grid_size
	boxes[:,:,:,2] = np.multiply(boxes[:,:,:,2],boxes[:,:,:,2])
	boxes[:,:,:,3] = np.multiply(boxes[:,:,:,3],boxes[:,:,:,3])
		
	boxes[:,:,:,0] *= w_img
	boxes[:,:,:,1] *= h_img
	boxes[:,:,:,2] *= w_img
	boxes[:,:,:,3] *= h_img

	for i in range(2):
		for j in range(num_class):
			probs[:,:,i,j] = np.multiply(class_probs[:,:,j],scales[:,:,i])
	filter_mat_probs = np.array(probs>=threshold,dtype='bool')
	filter_mat_boxes = np.nonzero(filter_mat_probs)
	boxes_filtered = boxes[filter_mat_boxes[0],filter_mat_boxes[1],filter_mat_boxes[2]]
	probs_filtered = probs[filter_mat_probs]
	classes_num_filtered = np.argmax(probs,axis=3)[filter_mat_boxes[0],filter_mat_boxes[1],filter_mat_boxes[2]]

	argsort = np.array(np.argsort(probs_filtered))[::-1]
	boxes_filtered = boxes_filtered[argsort]
	probs_filtered = probs_filtered[argsort]
	classes_num_filtered = classes_num_filtered[argsort]
		
	for i in range(len(boxes_filtered)):
		if probs_filtered[i] == 0 : continue
		for j in range(i+1,len(boxes_filtered)):
			if iou(boxes_filtered[i],boxes_filtered[j]) > iou_threshold : 
				probs_filtered[j] = 0.0
		
	filter_iou = np.array(probs_filtered>0.0,dtype='bool')
	boxes_filtered = boxes_filtered[filter_iou]
	probs_filtered = probs_filtered[filter_iou]
	classes_num_filtered = classes_num_filtered[filter_iou]

	result = []
	for i in range(len(boxes_filtered)):
		result.append([classes[classes_num_filtered[i]],boxes_filtered[i][0],boxes_filtered[i][1],boxes_filtered[i][2],boxes_filtered[i][3],probs_filtered[i]])

	return result

def iou(box1,box2):
	tb = min(box1[0]+0.5*box1[2],box2[0]+0.5*box2[2])-max(box1[0]-0.5*box1[2],box2[0]-0.5*box2[2])
	lr = min(box1[1]+0.5*box1[3],box2[1]+0.5*box2[3])-max(box1[1]-0.5*box1[3],box2[1]-0.5*box2[3])
	if tb < 0 or lr < 0 : intersection = 0
	else : intersection =  tb*lr
	return intersection / (box1[2]*box1[3] + box2[2]*box2[3] - intersection)

#YOLOV2
#reference from https://github.com/experiencor/keras-yolo2
# https://github.com/experiencor/keras-yolo2/blob/master/LICENSE
def interpret_output_yolov2(output, img_width, img_height):
	anchors=[0.57273, 0.677385, 1.87446, 2.06253, 3.33843, 5.47434, 7.88282, 3.52778, 9.77052, 9.16828]

	netout=output
	nb_class=1
	obj_threshold=0.4
	nms_threshold=0.3

	grid_h, grid_w, nb_box = netout.shape[:3]

	size = 4 + nb_class + 1;
	nb_box=5

	netout=netout.reshape(grid_h,grid_w,nb_box,size)

	boxes = []
	
	# decode the output by the network
	netout[..., 4]  = _sigmoid(netout[..., 4])
	netout[..., 5:] = netout[..., 4][..., np.newaxis] * _softmax(netout[..., 5:])
	netout[..., 5:] *= netout[..., 5:] > obj_threshold

	for row in range(grid_h):
		for col in range(grid_w):
			for b in range(nb_box):
				# from 4th element onwards are confidence and class classes
				classes = netout[row,col,b,5:]
				
				if np.sum(classes) > 0:
					# first 4 elements are x, y, w, and h
					x, y, w, h = netout[row,col,b,:4]

					x = (col + _sigmoid(x)) / grid_w # center position, unit: image width
					y = (row + _sigmoid(y)) / grid_h # center position, unit: image height
					w = anchors[2 * b + 0] * np.exp(w) / grid_w # unit: image width
					h = anchors[2 * b + 1] * np.exp(h) / grid_h # unit: image height
					confidence = netout[row,col,b,4]
					
					box = bounding_box(x-w/2, y-h/2, x+w/2, y+h/2, confidence, classes)
					
					boxes.append(box)

	# suppress non-maximal boxes
	for c in range(nb_class):
		sorted_indices = list(reversed(np.argsort([box.classes[c] for box in boxes])))

		for i in range(len(sorted_indices)):
			index_i = sorted_indices[i]
			
			if boxes[index_i].classes[c] == 0: 
				continue
			else:
				for j in range(i+1, len(sorted_indices)):
					index_j = sorted_indices[j]
					
					if bbox_iou(boxes[index_i], boxes[index_j]) >= nms_threshold:
						boxes[index_j].classes[c] = 0
						
	# remove the boxes which are less likely than a obj_threshold
	boxes = [box for box in boxes if box.get_score() > obj_threshold]
	
	result = []
	for i in range(len(boxes)):
		if(boxes[i].classes[0]==0):
			continue
		predicted_class = "face"
		score = boxes[i].score
		result.append([predicted_class,(boxes[i].xmax+boxes[i].xmin)*img_width/2,(boxes[i].ymax+boxes[i].ymin)*img_height/2,(boxes[i].xmax-boxes[i].xmin)*img_width,(boxes[i].ymax-boxes[i].ymin)*img_height,score])

	return result

class bounding_box:
	def __init__(self, xmin, ymin, xmax, ymax, c = None, classes = None):
		self.xmin = xmin
		self.ymin = ymin
		self.xmax = xmax
		self.ymax = ymax
		
		self.c     = c
		self.classes = classes

		self.label = -1
		self.score = -1

	def get_label(self):
		if self.label == -1:
			self.label = np.argmax(self.classes)
		
		return self.label
	
	def get_score(self):
		if self.score == -1:
			self.score = self.classes[self.get_label()]
			
		return self.score

def bbox_iou(box1, box2):
	intersect_w = _interval_overlap([box1.xmin, box1.xmax], [box2.xmin, box2.xmax])
	intersect_h = _interval_overlap([box1.ymin, box1.ymax], [box2.ymin, box2.ymax])  
	
	intersect = intersect_w * intersect_h

	w1, h1 = box1.xmax-box1.xmin, box1.ymax-box1.ymin
	w2, h2 = box2.xmax-box2.xmin, box2.ymax-box2.ymin
	
	union = w1*h1 + w2*h2 - intersect
	
	return float(intersect) / union

def _interval_overlap(interval_a, interval_b):
	x1, x2 = interval_a
	x3, x4 = interval_b

	if x3 < x1:
		if x4 < x1:
			return 0
		else:
			return min(x2,x4) - x1
	else:
		if x2 < x3:
			 return 0
		else:
			return min(x2,x4) - x3          

def _sigmoid(x):
	return 1. / (1. + np.exp(-x))

def _softmax(x, axis=-1, t=-100.):
	x = x - np.max(x)
	
	if np.min(x) < t:
		x = x/np.min(x)*t
		
	e_x = np.exp(x)
	
	return e_x / e_x.sum(axis, keepdims=True)

#crop
def crop(x,y,w,h,margin,img_width,img_height):
	xmin = int(x-w*margin)
	xmax = int(x+w*margin)
	ymin = int(y-h*margin)
	ymax = int(y+h*margin)
	if xmin<0:
		xmin = 0
	if ymin<0:
		ymin = 0
	if xmax>img_width:
		xmax = img_width
	if ymax>img_height:
		ymax = img_height
	return xmin,xmax,ymin,ymax

#display result
def show_results(img,results, img_width, img_height, model_age, model_gender, model_emotion, image_path):
	img_cp = img.copy()
	for i in range(len(results)):
		#display detected face
		x = int(results[i][1])
		y = int(results[i][2])
		w = int(results[i][3])//2
		h = int(results[i][4])//2

		if(w<h):
			w=h
		else:
			h=w

		xmin,xmax,ymin,ymax=crop(x,y,w,h,1.0,img_width,img_height)

		cv2.rectangle(img_cp,(xmin,ymin),(xmax,ymax),(0,255,0),2)
		#cv2.rectangle(img_cp,(xmin,ymin-20),(xmax,ymin),(125,125,125),-1)
		cv2.putText(img_cp,results[i][0] + ' : %.2f' % results[i][5],(xmin+5,ymin-7),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,0),1)

		target_image=img_cp

		#analyze detected face
		xmin2,xmax2,ymin2,ymax2=crop(x,y,w,h,1.1,img_width,img_height)

		face_image = img[ymin2:ymax2, xmin2:xmax2]

		if(face_image.shape[0]<=0 or face_image.shape[1]<=0):
			continue

		cv2.rectangle(target_image, (xmin2,ymin2), (xmax2,ymax2), color=(0,0,255), thickness=3)

		# offset=16

		# lines_age=open('words/agegender_age_words.txt').readlines()
		# lines_gender=open('words/agegender_gender_words.txt').readlines()
		# lines_fer2013=open('words/emotion_words.txt').readlines()
        # 
		# if(model_age!=None):
		# 	shape = model_age.layers[0].get_output_at(0).get_shape().as_list()
		# 	img_keras = cv2.resize(face_image, (shape[1],shape[2]))
		# 	#img_keras = img_keras[::-1, :, ::-1].copy()	#BGR to RGB
		# 	img_keras = np.expand_dims(img_keras, axis=0)
		# 	img_keras = img_keras / 255.0
        # 
		# 	pred_age_keras = model_age.predict(img_keras)[0]
		# 	prob_age_keras = np.max(pred_age_keras)
		# 	cls_age_keras = pred_age_keras.argmax()
        # 
		# 	age=0
		# 	for i in range(101):
		# 		age=age+pred_age_keras[i]*i
		# 	label=str(int(age))
        # 
		# 	#label="%.2f" % prob_age_keras + " " + lines_age[cls_age_keras]
        # 
		# 	cv2.putText(target_image, "Age : "+label, (xmin2,ymax2+offset), cv2.FONT_HERSHEY_COMPLEX_SMALL, 0.8, (0,0,250));
		# 	offset=offset+16
        # 
		# if(model_gender!=None):
		# 	shape = model_gender.layers[0].get_output_at(0).get_shape().as_list()
        # 
		# 	img_gender = cv2.resize(face_image, (shape[1],shape[2]))
		# 	#img_gender = img_gender[::-1, :, ::-1].copy()	#BGR to RGB
		# 	img_gender = np.expand_dims(img_gender, axis=0)
		# 	img_gender = img_gender / 255.0
        # 
		# 	pred_gender_keras = model_gender.predict(img_gender)[0]
		# 	prob_gender_keras = np.max(pred_gender_keras)
		# 	cls_gender_keras = pred_gender_keras.argmax()
		# 	cv2.putText(target_image, "Gender : %.2f" % prob_gender_keras + " " + lines_gender[cls_gender_keras], (xmin2,ymax2+offset), cv2.FONT_HERSHEY_COMPLEX_SMALL, 0.8, (0,0,250));
		# 	offset=offset+16
        # 
		# if(model_emotion!=None):
		# 	shape = model_emotion.layers[0].get_output_at(0).get_shape().as_list()
        # 
		# 	img_fer2013 = cv2.resize(face_image, (shape[1],shape[2]))
		# 	img_fer2013 = cv2.cvtColor(img_fer2013,cv2.COLOR_BGR2GRAY)
		# 	img_fer2013 = np.expand_dims(img_fer2013, axis=0)
		# 	img_fer2013 = np.expand_dims(img_fer2013, axis=3)
		# 	img_fer2013 = img_fer2013 / 255.0 *2 -1
        # 
		# 	pred_emotion_keras = model_emotion.predict(img_fer2013)[0]
		# 	prob_emotion_keras = np.max(pred_emotion_keras)
		# 	cls_emotion_keras = pred_emotion_keras.argmax()
		# 	cv2.putText(target_image, "Emotion : %.2f" % prob_emotion_keras + " " + lines_fer2013[cls_emotion_keras], (xmin2,ymax2+offset), cv2.FONT_HERSHEY_COMPLEX_SMALL, 0.8, (0,0,250));
		# 	offset=offset+16

	cv2.imwrite(image_path[:-4] + '_detected' + image_path[-4:],img_cp)

def preprocess_input(image, net_h, net_w):
    new_h, new_w, _ = image.shape

    # determine the new size of the image
    if (float(net_w)/new_w) < (float(net_h)/new_h):
        new_h = (new_h * net_w)/new_w
        new_w = net_w
    else:
        new_w = (new_w * net_h)/new_h
        new_h = net_h

    # resize the image to the new size
    resized = cv2.resize(image[:,:,::-1]/255., (int(new_w), int(new_h)))

    # embed the image into the standard letter box
    new_image = np.ones((net_h, net_w, 3)) * 0.5
    new_image[int((net_h-new_h)//2):int((net_h+new_h)//2), int((net_w-new_w)//2):int((net_w+new_w)//2), :] = resized
    new_image = np.expand_dims(new_image, 0)

    return new_image
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ###Make Prediction with Pre-trained model

# %%
def YOLOMain(image_path = ''):
    
    MODEL_ROOT_PATH="/content/FD/pretrain/"
    model_face = load_model(MODEL_ROOT_PATH+'yolov2_tiny-face.h5')
    # preprocess the image
    image = cv2.imread(image_path)
    image_h, image_w, _ = image.shape

    image = image[...,::-1]
    inputs = image.copy()/255.0
    img_cv = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    img_camera = cv2.resize(inputs, (416,416))
    img_camera = np.expand_dims(img_camera, axis=0)

    # new_image = preprocess_input(image, 416, 416)    

    yolo = model_face.predict(img_camera)[0]

    results = interpret_output_yolov2(yolo, image.shape[1], image.shape[0])
    show_results(img_cv, results, image.shape[1], image.shape[0], None, None, None, image_path)

# %%
import tensorflow

print(tensorflow.__version__)

if __name__=='__main__':
	YOLOMain(image_path='/content/SR/data/Aaron Judge/1.jpg')
# Out:
# 1.15.0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# /usr/local/lib/python3.7/dist-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %% [markdown]
# ##Util

# %%
# %cd /content/
# Out:
# /content

# %%
# !zip -r AJ_resized.zip /content/SR/data/AJ/
# Out:
#   adding: content/SR/data/AJ/ (stored 0%)
#   adding: content/SR/data/AJ/346 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/195 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/34 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/594 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/714 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/660 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/730 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/321 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/457 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/119 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/51 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/152 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/740 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/145 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/790 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/621 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/391 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/282 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/141 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/130 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/94 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/199 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/172 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/551 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/222 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/493 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/292 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/513 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/416 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/717 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/643 resized.jpg (deflated 4%)
#   adding: content/SR/data/AJ/309 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/335 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/140 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/750 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/530 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/371 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/373 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/326 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/456 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/583 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/484 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/426 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/22 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/318 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/743 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/397 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/83 resized.jpg (deflated 7%)
#   adding: content/SR/data/AJ/631 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/779 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/330 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/613 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/662 resized.jpg (deflated 3%)
#   adding: content/SR/data/AJ/485 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/764 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/515 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/353 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/669 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/638 resized.jpg (deflated 2%)
#   adding: content/SR/data/AJ/61 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/731 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/531 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/506 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/101 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/224 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/386 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/362 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/212 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/640 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/389 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/460 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/120 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/751 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/128 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/355 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/435 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/623 resized.jpg (deflated 5%)
#   adding: content/SR/data/AJ/488 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/216 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/77 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/46 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/315 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/682 resized.jpg (deflated 12%)
#   adding: content/SR/data/AJ/459 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/781 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/580 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/181 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/511 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/606 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/673 resized.jpg (deflated 7%)
#   adding: content/SR/data/AJ/733 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/106 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/96 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/708 resized.jpg (deflated 2%)
#   adding: content/SR/data/AJ/735 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/173 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/400 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/377 resized.jpg (deflated 7%)
#   adding: content/SR/data/AJ/784 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/105 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/75 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/372 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/271 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/747 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/107 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/63 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/137 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/142 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/566 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/110 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/465 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/737 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/527 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/559 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/88 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/794 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/275 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/126 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/305 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/605 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/134 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/306 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/187 resized.jpg (deflated 12%)
#   adding: content/SR/data/AJ/602 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/633 resized.jpg (deflated 2%)
#   adding: content/SR/data/AJ/39 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/290 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/753 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/92 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/80 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/482 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/567 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/514 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/7 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/285 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/78 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/132 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/250 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/255 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/741 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/179 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/31 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/189 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/630 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/430 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/376 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/742 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/674 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/191 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/403 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/410 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/58 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/489 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/35 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/157 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/380 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/561 resized.jpg (deflated 4%)
#   adding: content/SR/data/AJ/370 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/42 resized.jpg (deflated 6%)
#   adding: content/SR/data/AJ/32 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/692 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/38 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/358 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/608 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/95 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/761 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/363 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/796 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/770 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/791 resized.jpg (deflated 2%)
#   adding: content/SR/data/AJ/639 resized.jpg (deflated 3%)
#   adding: content/SR/data/AJ/401 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/454 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/556 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/113 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/242 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/334 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/681 resized.jpg (deflated 2%)
#   adding: content/SR/data/AJ/357 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/52 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/158 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/588 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/248 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/350 resized.jpg (deflated 2%)
#   adding: content/SR/data/AJ/85 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/207 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/659 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/787 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/417 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/125 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/693 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/14 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ/635 resized.jpg (deflated 1%)
#   adding: content/SR/data/AJ/719 resized.jpg (deflated 0%)
#   adding: content/SR/data/AJ